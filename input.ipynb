# %%
name=input('Name: ')
print('Greeting',name)
# Out:
# Name: Pandam
# Greeting Pandam

# %%
number=input('Number: ')
print(number+5)
# Out:
# Number: 8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-c0e61b4894d0> in <module>
#       1 number=input('Number: ')
# ----> 2 print(number+5)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# Burda hata veriyor çünkü verimizi string olarak alıyoruz ama üzerine int eklemeye çalışıyoruz. Çözüm ise aldığımız veriyi inte çevirmek

# %%
number=int(input('Number: '))
print(number+5)
# Out:
# Number: 7
# 12
