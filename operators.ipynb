# %%
print(25//2) #böleni en yakın tam sayıya yuvarlıyor
# Out:
# 12

# %% [markdown]
# pythonda bir yuvarlama olacaksa her zaman küçük sayıya yuvarlanır

# %%
print(27%5) #kalanı gösteriyor
print(5**3) #üstel sayılar için kullanılıyor
# Out:
# 2
# 125

# %%
x=5
x*=7 #x=x*7 ile aynı
print(x)
x/=5 #x=x/5 ile aynı
print(x)
# Out:
# 35
# 7.0

# %%
num1=15
num2=10
print(num1==num2)
print(num1!=num2)
print(num1<=num2)
print(num1>=num2)
# Out:
# False
# True
# False
# True

# %%
print(True and True)
print(True and False)
print(False and False)
print(True and True and False)
# Out:
# True
# False
# False
# False

# %%
print(True or False)
print(True or True)
print(False or False)
print(False or False or False or True)
# Out:
# True
# True
# False
# True

# %%
print('not True=', not True)
print('not False', not False)
# Out:
# not True= False
# not False True
