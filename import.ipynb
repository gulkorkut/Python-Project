# %%
import math
floor_number=(math.floor(2.0008))
print(floor_number,type(floor_number)) #yazılan sayıdan küçük en büyük tam sayıyı yaz
# Out:
# 2 <class 'int'>

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2022-08-24 19:01:45.355790

# %%
import random
print(random.randint(1,6)) #aslında bu bir basic dice roll, her çalıştırışında verdiğin aralıktan random bir sayı seçiyor
# Out:
# 4
